# %% [markdown]
# NER is a process of recognizing names, like person, organization and location names, and numeric expressions including time, date, money and percent expressions from unstructured text. The aim is to develop practical and domain-independent techniques in order to detect named entities with high accuracy automatically.

# %% [markdown]
# Our Task will be split into following Phases:-
#
#     1] Data Loading
#
#     2] Data Pre-Processing
#
#     3] Training ML models
#
#     4] Testing and Evaluation of Model Acuuracy
#
#     5] Model Monitoring by checking weights

# %% [markdown]
# ##### Loading Data

# %% [markdown]
# we are loading data corpus annotated with IOB and POS tags that can be found at Kaggle. We can have a quick peek of first several rows of the data. I am giving Kaggle link below.
# https://www.kaggle.com/abhinavwalia95/how-to-loading-and-fitting-dataset-to-scikit/data

# %%
import pandas as pd

dataset = pd.read_csv('ner_dataset.csv', encoding = "ISO-8859-1")

# %%
dataset.shape
# Out:
# (1048575, 4)

# %%
dataset.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %% [markdown]
# Woow!!! thats a huge dataset and perfect to train our models,though for speedy processing on my laptop I will be considering nly 100000 rows

# %%
quick_df = dataset[:50000]
quick_df.shape
# Out:
# (50000, 4)

# %% [markdown]
# Let us look for NA values and handle them selectively

# %%
quick_df.isnull().sum()
# Out:
# Sentence #    47730
# Word              0
# POS               0
# Tag               0
# dtype: int64

# %%
quick_df = quick_df.fillna(method = 'ffill')
quick_df
# Out:
#            Sentence #            Word  POS    Tag
# 0         Sentence: 1       Thousands  NNS      O
# 1         Sentence: 1              of   IN      O
# 2         Sentence: 1   demonstrators  NNS      O
# 3         Sentence: 1            have  VBP      O
# 4         Sentence: 1         marched  VBN      O
# 5         Sentence: 1         through   IN      O
# 6         Sentence: 1          London  NNP  B-geo
# 7         Sentence: 1              to   TO      O
# 8         Sentence: 1         protest   VB      O
# 9         Sentence: 1             the   DT      O
# 10        Sentence: 1             war   NN      O
# 11        Sentence: 1              in   IN      O
# 12        Sentence: 1            Iraq  NNP  B-geo
# 13        Sentence: 1             and   CC      O
# 14        Sentence: 1          demand   VB      O
# 15        Sentence: 1             the   DT      O
# 16        Sentence: 1      withdrawal   NN      O
# 17        Sentence: 1              of   IN      O
# 18        Sentence: 1         British   JJ  B-gpe
# 19        Sentence: 1          troops  NNS      O
# 20        Sentence: 1            from   IN      O
# 21        Sentence: 1            that   DT      O
# 22        Sentence: 1         country   NN      O
# 23        Sentence: 1               .    .      O
# 24        Sentence: 2        Families  NNS      O
# 25        Sentence: 2              of   IN      O
# 26        Sentence: 2        soldiers  NNS      O
# 27        Sentence: 2          killed  VBN      O
# 28        Sentence: 2              in   IN      O
# 29        Sentence: 2             the   DT      O
# ...               ...             ...  ...    ...
# 49970  Sentence: 2269          rebels  NNS      O
# 49971  Sentence: 2269               ,    ,      O
# 49972  Sentence: 2269        soldiers  NNS      O
# 49973  Sentence: 2269             and   CC      O
# 49974  Sentence: 2269           local   JJ      O
# 49975  Sentence: 2269       villagers  NNS      O
# 49976  Sentence: 2269          killed  VBD      O
# 49977  Sentence: 2269             the   DT      O
# 49978  Sentence: 2269       elephants  NNS      O
# 49979  Sentence: 2269               .    .      O
# 49980  Sentence: 2270             The   DT      O
# 49981  Sentence: 2270           group   NN      O
# 49982  Sentence: 2270          blames  VBZ      O
# 49983  Sentence: 2270             the   DT      O
# 49984  Sentence: 2270           surge   NN      O
# 49985  Sentence: 2270              in   IN      O
# 49986  Sentence: 2270        poaching  VBG      O
# 49987  Sentence: 2270              on   IN      O
# 49988  Sentence: 2270             the   DT      O
# 49989  Sentence: 2270  liberalization   NN      O
# 49990  Sentence: 2270              of   IN      O
# 49991  Sentence: 2270             the   DT      O
# 49992  Sentence: 2270           ivory   NN      O
# 49993  Sentence: 2270           trade   NN      O
# 49994  Sentence: 2270           being  VBG      O
# 49995  Sentence: 2270          pushed  VBN      O
# 49996  Sentence: 2270              by   IN      O
# 49997  Sentence: 2270           South  NNP  B-geo
# 49998  Sentence: 2270          Africa  NNP  I-geo
# 49999  Sentence: 2270               ,    ,      O
#
# [50000 rows x 4 columns]

# %%
quick_df['Sentence #'].nunique(),quick_df.Word.nunique(),quick_df.Tag.nunique()
# Out:
# (2270, 7464, 17)

# %% [markdown]
# We have 4,544 unique sentences that contain 10,922 unique words and tagged by 17 tags.

# %%
quick_df.groupby('Tag').size()
# Out:
# Tag
# B-art       48
# B-eve       39
# B-geo     1490
# B-gpe      968
# B-nat       18
# B-org      959
# B-per      789
# B-tim      880
# I-art       27
# I-eve       33
# I-geo      303
# I-gpe       31
# I-nat        9
# I-org      689
# I-per      931
# I-tim      239
# O        42547
# dtype: int64

# %% [markdown]
# Let create dataset for training our ML model, consisting of seperate input features and output features

# %%
X = quick_df.drop('Tag', axis=1)
X.head()
# Out:
#     Sentence #           Word  POS
# 0  Sentence: 1      Thousands  NNS
# 1  Sentence: 1             of   IN
# 2  Sentence: 1  demonstrators  NNS
# 3  Sentence: 1           have  VBP
# 4  Sentence: 1        marched  VBN

# %%
X.shape
# Out:
# (50000, 3)

# %%
X.columns
# Out:
# Index(['Sentence #', 'Word', 'POS'], dtype='object')

# %%
#Convert every record in to a dictionary
X.to_dict('records')
# Out:
# [{'POS': 'NNS', 'Sentence #': 'Sentence: 1', 'Word': 'Thousands'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 1', 'Word': 'of'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 1', 'Word': 'demonstrators'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 1', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 1', 'Word': 'marched'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 1', 'Word': 'through'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 1', 'Word': 'London'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 1', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 1', 'Word': 'protest'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 1', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 1', 'Word': 'war'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 1', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 1', 'Word': 'Iraq'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 1', 'Word': 'and'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 1', 'Word': 'demand'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 1', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 1', 'Word': 'withdrawal'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 1', 'Word': 'of'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 1', 'Word': 'British'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 1', 'Word': 'troops'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 1', 'Word': 'from'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 1', 'Word': 'that'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 1', 'Word': 'country'},
#  {'POS': '.', 'Sentence #': 'Sentence: 1', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'Families'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 2', 'Word': 'of'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'soldiers'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 2', 'Word': 'killed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 2', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 2', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 2', 'Word': 'conflict'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 2', 'Word': 'joined'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 2', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'protesters'},
#  {'POS': 'WP', 'Sentence #': 'Sentence: 2', 'Word': 'who'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 2', 'Word': 'carried'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'banners'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 2', 'Word': 'with'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 2', 'Word': 'such'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'slogans'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 2', 'Word': 'as'},
#  {'POS': '``', 'Sentence #': 'Sentence: 2', 'Word': '"'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 2', 'Word': 'Bush'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 2', 'Word': 'Number'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 2', 'Word': 'One'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 2', 'Word': 'Terrorist'},
#  {'POS': '``', 'Sentence #': 'Sentence: 2', 'Word': '"'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 2', 'Word': 'and'},
#  {'POS': '``', 'Sentence #': 'Sentence: 2', 'Word': '"'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 2', 'Word': 'Stop'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 2', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 2', 'Word': 'Bombings'},
#  {'POS': '.', 'Sentence #': 'Sentence: 2', 'Word': '.'},
#  {'POS': '``', 'Sentence #': 'Sentence: 2', 'Word': '"'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 3', 'Word': 'They'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 3', 'Word': 'marched'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 3', 'Word': 'from'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 3', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 3', 'Word': 'Houses'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 3', 'Word': 'of'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 3', 'Word': 'Parliament'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 3', 'Word': 'to'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 3', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 3', 'Word': 'rally'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 3', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 3', 'Word': 'Hyde'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 3', 'Word': 'Park'},
#  {'POS': '.', 'Sentence #': 'Sentence: 3', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 4', 'Word': 'Police'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 4', 'Word': 'put'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 4', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 4', 'Word': 'number'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 4', 'Word': 'of'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 4', 'Word': 'marchers'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 4', 'Word': 'at'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 4', 'Word': '10,000'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 4', 'Word': 'while'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 4', 'Word': 'organizers'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 4', 'Word': 'claimed'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 4', 'Word': 'it'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 4', 'Word': 'was'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 4', 'Word': '1,00,000'},
#  {'POS': '.', 'Sentence #': 'Sentence: 4', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 5', 'Word': 'The'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 5', 'Word': 'protest'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 5', 'Word': 'comes'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 5', 'Word': 'on'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 5', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 5', 'Word': 'eve'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 5', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 5', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 5', 'Word': 'annual'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 5', 'Word': 'conference'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 5', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 5', 'Word': 'Britain'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 5', 'Word': "'s"},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 5', 'Word': 'ruling'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 5', 'Word': 'Labor'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 5', 'Word': 'Party'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 5', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 5', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 5', 'Word': 'southern'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 5', 'Word': 'English'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 5', 'Word': 'seaside'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 5', 'Word': 'resort'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 5', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 5', 'Word': 'Brighton'},
#  {'POS': '.', 'Sentence #': 'Sentence: 5', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 6', 'Word': 'The'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 6', 'Word': 'party'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 6', 'Word': 'is'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 6', 'Word': 'divided'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 6', 'Word': 'over'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 6', 'Word': 'Britain'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 6', 'Word': "'s"},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 6', 'Word': 'participation'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 6', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 6', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 6', 'Word': 'Iraq'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 6', 'Word': 'conflict'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 6', 'Word': 'and'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 6', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 6', 'Word': 'continued'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 6', 'Word': 'deployment'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 6', 'Word': 'of'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 6', 'Word': '8,500'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 6', 'Word': 'British'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 6', 'Word': 'troops'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 6', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 6', 'Word': 'that'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 6', 'Word': 'country'},
#  {'POS': '.', 'Sentence #': 'Sentence: 6', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 7', 'Word': 'The'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 7', 'Word': 'London'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 7', 'Word': 'march'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 7', 'Word': 'came'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 7', 'Word': 'ahead'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 7', 'Word': 'of'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 7', 'Word': 'anti-war'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 7', 'Word': 'protests'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 7', 'Word': 'today'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 7', 'Word': 'in'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 7', 'Word': 'other'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 7', 'Word': 'cities'},
#  {'POS': ',', 'Sentence #': 'Sentence: 7', 'Word': ','},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 7', 'Word': 'including'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 7', 'Word': 'Rome'},
#  {'POS': ',', 'Sentence #': 'Sentence: 7', 'Word': ','},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 7', 'Word': 'Paris'},
#  {'POS': ',', 'Sentence #': 'Sentence: 7', 'Word': ','},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 7', 'Word': 'and'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 7', 'Word': 'Madrid'},
#  {'POS': '.', 'Sentence #': 'Sentence: 7', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 8', 'Word': 'The'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'International'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Atomic'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Energy'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Agency'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 8', 'Word': 'is'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 8', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 8', 'Word': 'hold'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 8', 'Word': 'second'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 8', 'Word': 'day'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 8', 'Word': 'of'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 8', 'Word': 'talks'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 8', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Vienna'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Wednesday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 8', 'Word': 'on'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 8', 'Word': 'how'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 8', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 8', 'Word': 'respond'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 8', 'Word': 'to'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 8', 'Word': 'Iran'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 8', 'Word': "'s"},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 8', 'Word': 'resumption'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 8', 'Word': 'of'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 8', 'Word': 'low-level'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 8', 'Word': 'uranium'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 8', 'Word': 'conversion'},
#  {'POS': '.', 'Sentence #': 'Sentence: 8', 'Word': '.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 9', 'Word': 'Iran'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 9', 'Word': 'this'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 9', 'Word': 'week'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 9', 'Word': 'restarted'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 9', 'Word': 'parts'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 9', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 9', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 9', 'Word': 'conversion'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 9', 'Word': 'process'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 9', 'Word': 'at'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 9', 'Word': 'its'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 9', 'Word': 'Isfahan'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 9', 'Word': 'nuclear'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 9', 'Word': 'plant'},
#  {'POS': '.', 'Sentence #': 'Sentence: 9', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 10', 'Word': 'Iranian'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 10', 'Word': 'officials'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 10', 'Word': 'say'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 10', 'Word': 'they'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 10', 'Word': 'expect'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 10', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 10', 'Word': 'get'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 10', 'Word': 'access'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 10', 'Word': 'to'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 10', 'Word': 'sealed'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 10', 'Word': 'sensitive'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 10', 'Word': 'parts'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 10', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 10', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 10', 'Word': 'plant'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 10', 'Word': 'Wednesday'},
#  {'POS': ',', 'Sentence #': 'Sentence: 10', 'Word': ','},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 10', 'Word': 'after'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 10', 'Word': 'an'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 10', 'Word': 'IAEA'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 10', 'Word': 'surveillance'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 10', 'Word': 'system'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 10', 'Word': 'begins'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 10', 'Word': 'functioning'},
#  {'POS': '.', 'Sentence #': 'Sentence: 10', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 11', 'Word': 'The'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 11', 'Word': 'step'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 11', 'Word': 'will'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 11', 'Word': 'allow'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 11', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 11', 'Word': 'facility'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 11', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 11', 'Word': 'operate'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 11', 'Word': 'at'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 11', 'Word': 'full'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 11', 'Word': 'capacity'},
#  {'POS': '.', 'Sentence #': 'Sentence: 11', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 12', 'Word': 'The'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'European'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Union'},
#  {'POS': ',', 'Sentence #': 'Sentence: 12', 'Word': ','},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 12', 'Word': 'with'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'U.S.'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 12', 'Word': 'backing'},
#  {'POS': ',', 'Sentence #': 'Sentence: 12', 'Word': ','},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 12', 'Word': 'has'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 12', 'Word': 'threatened'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 12', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 12', 'Word': 'refer'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Iran'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 12', 'Word': 'to'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 12', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'U.N.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Security'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Council'},
#  {'POS': ',', 'Sentence #': 'Sentence: 12', 'Word': ','},
#  {'POS': 'WDT', 'Sentence #': 'Sentence: 12', 'Word': 'which'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 12', 'Word': 'could'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 12', 'Word': 'impose'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 12', 'Word': 'sanctions'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 12', 'Word': 'if'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 12', 'Word': 'it'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 12', 'Word': 'finds'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Tehran'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 12', 'Word': 'has'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 12', 'Word': 'violated'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 12', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Nuclear'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 12', 'Word': 'Non-Proliferation'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 12', 'Word': 'treaty'},
#  {'POS': '.', 'Sentence #': 'Sentence: 12', 'Word': '.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'Iran'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 13', 'Word': "'s"},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 13', 'Word': 'new'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'President'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'Mahmoud'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'Ahmadinejad'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 13', 'Word': 'said'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'Tuesday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 13', 'Word': 'that'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 13', 'Word': 'European'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 13', 'Word': 'incentives'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 13', 'Word': 'aimed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 13', 'Word': 'at'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 13', 'Word': 'persuading'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 13', 'Word': 'Iran'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 13', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 13', 'Word': 'end'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 13', 'Word': 'its'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 13', 'Word': 'nuclear'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 13', 'Word': 'fuel'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 13', 'Word': 'program'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 13', 'Word': 'are'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 13', 'Word': 'an'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 13', 'Word': 'insult'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 13', 'Word': 'to'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 13', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 13', 'Word': 'Iranian'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 13', 'Word': 'nation'},
#  {'POS': '.', 'Sentence #': 'Sentence: 13', 'Word': '.'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 14', 'Word': 'Two'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 14', 'Word': 'Germans'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 14', 'Word': 'and'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 14', 'Word': 'four'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 14', 'Word': 'Nigerian'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 14', 'Word': 'oil'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 14', 'Word': 'workers'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 14', 'Word': 'were'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 14', 'Word': 'kidnapped'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 14', 'Word': 'by'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 14', 'Word': 'armed'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 14', 'Word': 'militants'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 14', 'Word': 'during'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 14', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 14', 'Word': 'raid'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 14', 'Word': 'on'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 14', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 14', 'Word': 'boat'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 14', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 14', 'Word': 'Nigeria'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 14', 'Word': "'s"},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 14', 'Word': 'southern'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 14', 'Word': 'oil-rich'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 14', 'Word': 'Delta'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 14', 'Word': 'region'},
#  {'POS': '.', 'Sentence #': 'Sentence: 14', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 15', 'Word': 'An'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'official'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 15', 'Word': 'with'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 15', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 15', 'Word': 'German'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'firm'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Bilfinger'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Berger'},
#  {'POS': ',', 'Sentence #': 'Sentence: 15', 'Word': ','},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Thomas'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Horbach'},
#  {'POS': ',', 'Sentence #': 'Sentence: 15', 'Word': ','},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 15', 'Word': 'said'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 15', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 15', 'Word': 'gunmen'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 15', 'Word': 'stopped'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 15', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'supply'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'boat'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Wednesday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 15', 'Word': 'as'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 15', 'Word': 'it'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 15', 'Word': 'sailed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 15', 'Word': 'from'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Delta'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'State'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 15', 'Word': 'to'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Bayelsa'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'State'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 15', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 15', 'Word': 'inspect'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 15', 'Word': 'an'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 15', 'Word': 'offshore'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'oil'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 15', 'Word': 'field'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 15', 'Word': 'owned'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 15', 'Word': 'by'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Royal-Dutch'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 15', 'Word': 'Shell'},
#  {'POS': '.', 'Sentence #': 'Sentence: 15', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 16', 'Word': 'The'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 16', 'Word': 'German'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 16', 'Word': 'firm'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 16', 'Word': 'works'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 16', 'Word': 'as'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 16', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 16', 'Word': 'sub-contractor'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 16', 'Word': 'for'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 16', 'Word': 'Shell'},
#  {'POS': '.', 'Sentence #': 'Sentence: 16', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 17', 'Word': 'Militant'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 17', 'Word': 'groups'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 17', 'Word': 'frequently'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 17', 'Word': 'attack'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 17', 'Word': 'oil'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 17', 'Word': 'operations'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 17', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 17', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 17', 'Word': 'Niger'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 17', 'Word': 'Delta'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 17', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 17', 'Word': 'demand'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 17', 'Word': 'social'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 17', 'Word': 'services'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 17', 'Word': 'and'},
#  {'POS': 'JJR', 'Sentence #': 'Sentence: 17', 'Word': 'better'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 17', 'Word': 'job'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 17', 'Word': 'opportunities'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 17', 'Word': 'from'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 17', 'Word': 'multinational'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 17', 'Word': 'companies'},
#  {'POS': '.', 'Sentence #': 'Sentence: 17', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 18', 'Word': 'Poor'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 18', 'Word': 'residents'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 18', 'Word': 'often'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 18', 'Word': 'complain'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 18', 'Word': 'they'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 18', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 18', 'Word': 'been'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 18', 'Word': 'cheated'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 18', 'Word': 'out'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 18', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 18', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 18', 'Word': 'huge'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 18', 'Word': 'riches'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 18', 'Word': 'extracted'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 18', 'Word': 'from'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 18', 'Word': 'their'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 18', 'Word': 'tribal'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 18', 'Word': 'lands'},
#  {'POS': ':', 'Sentence #': 'Sentence: 18', 'Word': '-'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 18', 'Word': 'where'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 18', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 18', 'Word': 'bulk'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 18', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 18', 'Word': 'Nigeria'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 18', 'Word': "'s"},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 18', 'Word': '2.3'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 18', 'Word': 'million'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 18', 'Word': 'barrels'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 18', 'Word': 'of'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 18', 'Word': 'petroleum'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 18', 'Word': 'are'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 18', 'Word': 'pumped'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 18', 'Word': 'daily'},
#  {'POS': '.', 'Sentence #': 'Sentence: 18', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 19', 'Word': 'Suspected'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 19', 'Word': 'Islamist'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 19', 'Word': 'rebels'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 19', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 19', 'Word': 'fired'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 19', 'Word': 'mortar'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 19', 'Word': 'shells'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 19', 'Word': 'at'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 19', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 19', 'Word': 'palace'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 19', 'Word': 'used'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 19', 'Word': 'by'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 19', 'Word': 'Somalia'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 19', 'Word': "'s"},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 19', 'Word': 'interim'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 19', 'Word': 'President'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 19', 'Word': 'Abdullahi'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 19', 'Word': 'Yusuf'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 19', 'Word': 'Ahmad'},
#  {'POS': '.', 'Sentence #': 'Sentence: 19', 'Word': '.'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 20', 'Word': 'It'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 20', 'Word': 'was'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 20', 'Word': 'not'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 20', 'Word': 'immediately'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 20', 'Word': 'clear'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 20', 'Word': 'if'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 20', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 20', 'Word': 'president'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 20', 'Word': 'was'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 20', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 20', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 20', 'Word': 'palace'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 20', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 20', 'Word': 'Mogadishu'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 20', 'Word': 'when'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 20', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 20', 'Word': 'attack'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 20', 'Word': 'occurred'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 20', 'Word': 'or'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 20', 'Word': 'if'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 20', 'Word': 'anyone'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 20', 'Word': 'was'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 20', 'Word': 'hurt'},
#  {'POS': '.', 'Sentence #': 'Sentence: 20', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 21', 'Word': 'Local'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 21', 'Word': 'news'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 21', 'Word': 'reports'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 21', 'Word': 'said'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 21', 'Word': 'at'},
#  {'POS': 'JJS', 'Sentence #': 'Sentence: 21', 'Word': 'least'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 21', 'Word': 'five'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 21', 'Word': 'mortar'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 21', 'Word': 'shells'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 21', 'Word': 'hit'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 21', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 21', 'Word': 'palace'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 21', 'Word': 'compound'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 21', 'Word': 'and'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 21', 'Word': 'other'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 21', 'Word': 'mortars'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 21', 'Word': 'were'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 21', 'Word': 'fired'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 21', 'Word': 'elsewhere'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 21', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 21', 'Word': 'Mogadishu'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 21', 'Word': 'Wednesday'},
#  {'POS': '.', 'Sentence #': 'Sentence: 21', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 22', 'Word': 'The'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 22', 'Word': 'attacks'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 22', 'Word': 'occurred'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 22', 'Word': 'after'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 22', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 22', 'Word': 'government'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 22', 'Word': 'said'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 22', 'Word': 'it'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 22', 'Word': 'will'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 22', 'Word': 'go'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 22', 'Word': 'ahead'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 22', 'Word': 'with'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 22', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 22', 'Word': 'reconciliation'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 22', 'Word': 'conference'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 22', 'Word': 'to'},
#  {'POS': 'WDT', 'Sentence #': 'Sentence: 22', 'Word': 'which'},
#  {'POS': 'JJR', 'Sentence #': 'Sentence: 22', 'Word': 'more'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 22', 'Word': 'than'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 22', 'Word': '1,300'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 22', 'Word': 'Somali'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 22', 'Word': 'elders'},
#  {'POS': ',', 'Sentence #': 'Sentence: 22', 'Word': ','},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 22', 'Word': 'warlords'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 22', 'Word': 'and'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 22', 'Word': 'politicians'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 22', 'Word': 'are'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 22', 'Word': 'invited'},
#  {'POS': '.', 'Sentence #': 'Sentence: 22', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 23', 'Word': 'Iraqi'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 23', 'Word': 'military'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 23', 'Word': 'officials'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 23', 'Word': 'say'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 23', 'Word': 'tanks'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 23', 'Word': 'and'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 23', 'Word': 'troops'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 23', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 23', 'Word': 'arrived'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 23', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 23', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 23', 'Word': 'northern'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 23', 'Word': 'city'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 23', 'Word': 'Mosul'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 23', 'Word': 'for'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 23', 'Word': 'a'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 23', 'Word': 'new'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 23', 'Word': 'offensive'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 23', 'Word': 'against'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 23', 'Word': 'al'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 23', 'Word': 'Qaida'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 23', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 23', 'Word': 'Iraq'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 23', 'Word': 'fighters'},
#  {'POS': '.', 'Sentence #': 'Sentence: 23', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 24', 'Word': 'Officials'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 24', 'Word': 'will'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 24', 'Word': 'not'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 24', 'Word': 'say'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 24', 'Word': 'how'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 24', 'Word': 'many'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 24', 'Word': 'troops'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 24', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 24', 'Word': 'arrived'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 24', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 24', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 24', 'Word': 'Sunni'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 24', 'Word': 'Arab'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 24', 'Word': 'and'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 24', 'Word': 'Kurdish'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 24', 'Word': 'city'},
#  {'POS': ',', 'Sentence #': 'Sentence: 24', 'Word': ','},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 24', 'Word': 'where'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 24', 'Word': 'bombings'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 24', 'Word': 'last'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 24', 'Word': 'week'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 24', 'Word': 'killed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 24', 'Word': 'at'},
#  {'POS': 'JJS', 'Sentence #': 'Sentence: 24', 'Word': 'least'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 24', 'Word': '34'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 24', 'Word': 'people'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 24', 'Word': 'and'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 24', 'Word': 'wounded'},
#  {'POS': 'JJR', 'Sentence #': 'Sentence: 24', 'Word': 'more'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 24', 'Word': 'than'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 24', 'Word': '200'},
#  {'POS': '.', 'Sentence #': 'Sentence: 24', 'Word': '.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 25', 'Word': 'U.S.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 25', 'Word': 'commanders'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 25', 'Word': 'have'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 25', 'Word': 'not'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 25', 'Word': 'explained'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 25', 'Word': 'how'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 25', 'Word': 'American'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 25', 'Word': 'forces'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 25', 'Word': 'will'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 25', 'Word': 'participate'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 25', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 25', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 25', 'Word': 'offensive'},
#  {'POS': '.', 'Sentence #': 'Sentence: 25', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 26', 'Word': 'Officials'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 26', 'Word': 'say'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 26', 'Word': 'al'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 26', 'Word': 'Qaida'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 26', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 26', 'Word': 'Iraq'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 26', 'Word': 'fighters'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 26', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 26', 'Word': 'fled'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 26', 'Word': 'successful'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 26', 'Word': 'campaigns'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 26', 'Word': 'against'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 26', 'Word': 'them'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 26', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 26', 'Word': 'Anbar'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 26', 'Word': 'province'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 26', 'Word': 'and'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 26', 'Word': 'Baghdad'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 26', 'Word': 'to'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 26', 'Word': 'other'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 26', 'Word': 'northern'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 26', 'Word': 'provinces'},
#  {'POS': '.', 'Sentence #': 'Sentence: 26', 'Word': '.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 27', 'Word': 'Mosul'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 27', 'Word': 'is'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 27', 'Word': 'the'},
#  {'POS': 'JJS', 'Sentence #': 'Sentence: 27', 'Word': 'largest'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 27', 'Word': 'city'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 27', 'Word': 'north'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 27', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 27', 'Word': 'Baghdad'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 27', 'Word': 'and'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 27', 'Word': 'has'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 27', 'Word': 'long'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 27', 'Word': 'been'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 27', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 27', 'Word': 'stronghold'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 27', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 27', 'Word': 'Sunni'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 27', 'Word': 'militant'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 27', 'Word': 'fighters'},
#  {'POS': '.', 'Sentence #': 'Sentence: 27', 'Word': '.'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 28', 'Word': 'In'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 28', 'Word': 'other'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 28', 'Word': 'violence'},
#  {'POS': ',', 'Sentence #': 'Sentence: 28', 'Word': ','},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 28', 'Word': 'U.S.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 28', 'Word': 'officials'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 28', 'Word': 'said'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 28', 'Word': 'one'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 28', 'Word': 'American'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 28', 'Word': 'soldier'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 28', 'Word': 'was'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 28', 'Word': 'killed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 28', 'Word': 'while'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 28', 'Word': 'on'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 28', 'Word': 'patrol'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 28', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 28', 'Word': 'Baghdad'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 28', 'Word': 'Sunday'},
#  {'POS': '.', 'Sentence #': 'Sentence: 28', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 29', 'Word': 'Egyptian'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 29', 'Word': 'police'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 29', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 29', 'Word': 'arrested'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 29', 'Word': 'at'},
#  {'POS': 'JJS', 'Sentence #': 'Sentence: 29', 'Word': 'least'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 29', 'Word': '16'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 29', 'Word': 'members'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 29', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 29', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 29', 'Word': 'opposition'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 29', 'Word': 'Muslim'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 29', 'Word': 'Brotherhood'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 29', 'Word': 'as'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 29', 'Word': 'parts'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 29', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 29', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 29', 'Word': 'country'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 29', 'Word': 'prepare'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 29', 'Word': 'for'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 29', 'Word': 'parliamentary'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 29', 'Word': 'runoff'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 29', 'Word': 'elections'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 29', 'Word': 'Saturday'},
#  {'POS': '.', 'Sentence #': 'Sentence: 29', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 30', 'Word': 'The'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 30', 'Word': 'arrests'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 30', 'Word': 'occurred'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 30', 'Word': 'Friday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 30', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 30', 'Word': 'Alexandria'},
#  {'POS': '.', 'Sentence #': 'Sentence: 30', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 31', 'Word': 'A'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 31', 'Word': 'spokesman'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 31', 'Word': 'for'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 31', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 31', 'Word': 'Brotherhood'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 31', 'Word': 'said'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 31', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 31', 'Word': 'arrests'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 31', 'Word': 'are'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 31', 'Word': 'an'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 31', 'Word': 'attempt'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 31', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 31', 'Word': 'cut'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 31', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 31', 'Word': 'Brotherhood'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 31', 'Word': 'off'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 31', 'Word': 'from'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 31', 'Word': 'its'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 31', 'Word': 'supporters'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 31', 'Word': 'and'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 31', 'Word': 'punishment'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 31', 'Word': 'for'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 31', 'Word': 'winning'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 31', 'Word': 'parliamentary'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 31', 'Word': 'seats'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 31', 'Word': 'in'},
#  {'POS': 'JJR', 'Sentence #': 'Sentence: 31', 'Word': 'earlier'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 31', 'Word': 'elections'},
#  {'POS': '.', 'Sentence #': 'Sentence: 31', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 32', 'Word': 'The'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 32', 'Word': 'Muslim'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 32', 'Word': 'Brotherhood'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 32', 'Word': 'has'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 32', 'Word': 'tripled'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 32', 'Word': 'its'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 32', 'Word': 'strength'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 32', 'Word': 'in'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 32', 'Word': 'parliament'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 32', 'Word': 'in'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 32', 'Word': 'recent'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 32', 'Word': 'elections'},
#  {'POS': ',', 'Sentence #': 'Sentence: 32', 'Word': ','},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 32', 'Word': 'raising'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 32', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 32', 'Word': 'party'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 32', 'Word': "'s"},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 32', 'Word': 'total'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 32', 'Word': 'to'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 32', 'Word': '47'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 32', 'Word': 'seats'},
#  {'POS': '.', 'Sentence #': 'Sentence: 32', 'Word': '.'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 33', 'Word': 'In'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 33', 'Word': 'Saturday'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 33', 'Word': "'s"},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 33', 'Word': 'elections'},
#  {'POS': ',', 'Sentence #': 'Sentence: 33', 'Word': ','},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 33', 'Word': 'voters'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 33', 'Word': 'will'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 33', 'Word': 'cast'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 33', 'Word': 'ballots'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 33', 'Word': 'in'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 33', 'Word': 'nine'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 33', 'Word': 'provinces'},
#  {'POS': 'WRB', 'Sentence #': 'Sentence: 33', 'Word': 'where'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 33', 'Word': 'no'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 33', 'Word': 'candidate'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 33', 'Word': 'won'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 33', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 33', 'Word': 'majority'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 33', 'Word': 'in'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 33', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 33', 'Word': 'previous'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 33', 'Word': 'round'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 33', 'Word': 'of'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 33', 'Word': 'voting'},
#  {'POS': '.', 'Sentence #': 'Sentence: 33', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 34', 'Word': 'The'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 34', 'Word': 'Muslim'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 34', 'Word': 'Brotherhood'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 34', 'Word': 'is'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 34', 'Word': 'banned'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 34', 'Word': 'as'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 34', 'Word': 'a'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 34', 'Word': 'political'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 34', 'Word': 'party'},
#  {'POS': ',', 'Sentence #': 'Sentence: 34', 'Word': ','},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 34', 'Word': 'but'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 34', 'Word': 'it'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 34', 'Word': 'endorses'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 34', 'Word': 'so-called'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 34', 'Word': 'independent'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 34', 'Word': 'candidates'},
#  {'POS': 'WP$', 'Sentence #': 'Sentence: 34', 'Word': 'whose'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 34', 'Word': 'allegiance'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 34', 'Word': 'to'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 34', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 34', 'Word': 'party'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 34', 'Word': 'is'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 34', 'Word': 'known'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 34', 'Word': 'to'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 34', 'Word': 'voters'},
#  {'POS': '.', 'Sentence #': 'Sentence: 34', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 35', 'Word': 'Hardline'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 35', 'Word': 'lawmakers'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 35', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 35', 'Word': 'Pakistan'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 35', 'Word': "'s"},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 35', 'Word': 'North'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 35', 'Word': 'West'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 35', 'Word': 'Frontier'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 35', 'Word': 'Province'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 35', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 35', 'Word': 'pushed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 35', 'Word': 'through'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 35', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 35', 'Word': 'law'},
#  {'POS': 'WDT', 'Sentence #': 'Sentence: 35', 'Word': 'that'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 35', 'Word': 'aims'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 35', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 35', 'Word': 'ensure'},
#  {'POS': '``', 'Sentence #': 'Sentence: 35', 'Word': '"'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 35', 'Word': 'Islamic'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 35', 'Word': 'correctness'},
#  {'POS': '``', 'Sentence #': 'Sentence: 35', 'Word': '"'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 35', 'Word': 'in'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 35', 'Word': 'public'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 35', 'Word': 'places'},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 35', 'Word': 'and'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 35', 'Word': 'establishes'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 35', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 35', 'Word': 'morality'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 35', 'Word': 'police'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 35', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 35', 'Word': 'enforce'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 35', 'Word': 'decent'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 35', 'Word': 'behavior'},
#  {'POS': '.', 'Sentence #': 'Sentence: 35', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 36', 'Word': 'A'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 36', 'Word': 'six-party'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 36', 'Word': 'coalition'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 36', 'Word': 'of'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 36', 'Word': 'religious'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 36', 'Word': 'based'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 36', 'Word': 'parties'},
#  {'POS': ',', 'Sentence #': 'Sentence: 36', 'Word': ','},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 36', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 36', 'Word': 'Mutahida'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 36', 'Word': 'Majlis-e-Amal'},
#  {'POS': ',', 'Sentence #': 'Sentence: 36', 'Word': ','},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 36', 'Word': 'dominates'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 36', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 36', 'Word': 'provincial'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 36', 'Word': 'assembly'},
#  {'POS': ',', 'Sentence #': 'Sentence: 36', 'Word': ','},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 36', 'Word': 'so'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 36', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 36', 'Word': 'bill'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 36', 'Word': 'was'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 36', 'Word': 'easily'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 36', 'Word': 'passed'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 36', 'Word': 'Thursday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 36', 'Word': 'by'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 36', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 36', 'Word': 'vote'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 36', 'Word': 'of'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 36', 'Word': '68-34'},
#  {'POS': '.', 'Sentence #': 'Sentence: 36', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 37', 'Word': 'The'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 37', 'Word': 'provincial'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 37', 'Word': 'governor'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 37', 'Word': 'must'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 37', 'Word': 'still'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 37', 'Word': 'sign'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 37', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 37', 'Word': 'bill'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 37', 'Word': 'before'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 37', 'Word': 'it'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 37', 'Word': 'becomes'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 37', 'Word': 'law'},
#  {'POS': ',', 'Sentence #': 'Sentence: 37', 'Word': ','},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 37', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 37', 'Word': 'step'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 37', 'Word': 'seen'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 37', 'Word': 'only'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 37', 'Word': 'as'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 37', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 37', 'Word': 'formality'},
#  {'POS': '.', 'Sentence #': 'Sentence: 37', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 38', 'Word': 'The'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'proposed'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 38', 'Word': 'law'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 38', 'Word': 'calls'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 38', 'Word': 'for'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 38', 'Word': 'setting'},
#  {'POS': 'RP', 'Sentence #': 'Sentence: 38', 'Word': 'up'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 38', 'Word': 'a'},
#  {'POS': '``', 'Sentence #': 'Sentence: 38', 'Word': '"'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'religious'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 38', 'Word': 'police'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 38', 'Word': 'force'},
#  {'POS': '``', 'Sentence #': 'Sentence: 38', 'Word': '"'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 38', 'Word': 'to'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 38', 'Word': 'make'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'sure'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 38', 'Word': 'people'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 38', 'Word': 'adhere'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 38', 'Word': 'to'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'Islamic'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 38', 'Word': 'values'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 38', 'Word': 'in'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'public'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 38', 'Word': 'places'},
#  {'POS': ',', 'Sentence #': 'Sentence: 38', 'Word': ','},
#  {'POS': 'CC', 'Sentence #': 'Sentence: 38', 'Word': 'and'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 38', 'Word': 'entertainment'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 38', 'Word': 'outlets'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 38', 'Word': 'close'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 38', 'Word': 'during'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 38', 'Word': 'weekly'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 38', 'Word': 'Friday'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 38', 'Word': 'prayers'},
#  {'POS': '.', 'Sentence #': 'Sentence: 38', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 39', 'Word': 'Violators'},
#  {'POS': 'MD', 'Sentence #': 'Sentence: 39', 'Word': 'could'},
#  {'POS': 'VB', 'Sentence #': 'Sentence: 39', 'Word': 'be'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 39', 'Word': 'jailed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 39', 'Word': 'for'},
#  {'POS': 'RB', 'Sentence #': 'Sentence: 39', 'Word': 'up'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 39', 'Word': 'to'},
#  {'POS': 'CD', 'Sentence #': 'Sentence: 39', 'Word': 'six'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 39', 'Word': 'months'},
#  {'POS': '.', 'Sentence #': 'Sentence: 39', 'Word': '.'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 40', 'Word': 'The'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 40', 'Word': 'opposition'},
#  {'POS': 'VBZ', 'Sentence #': 'Sentence: 40', 'Word': 'has'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 40', 'Word': 'denounced'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 40', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 40', 'Word': 'measure'},
#  {'POS': ',', 'Sentence #': 'Sentence: 40', 'Word': ','},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 40', 'Word': 'comparing'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 40', 'Word': 'it'},
#  {'POS': 'TO', 'Sentence #': 'Sentence: 40', 'Word': 'to'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 40', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 40', 'Word': 'draconian'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 40', 'Word': 'rule'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 40', 'Word': 'of'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 40', 'Word': 'the'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 40', 'Word': 'former'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 40', 'Word': 'Taleban'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 40', 'Word': 'in'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 40', 'Word': 'neighboring'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 40', 'Word': 'Afghanistan'},
#  {'POS': '.', 'Sentence #': 'Sentence: 40', 'Word': '.'},
#  {'POS': 'JJ', 'Sentence #': 'Sentence: 41', 'Word': 'British'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 41', 'Word': 'police'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 41', 'Word': 'say'},
#  {'POS': 'PRP', 'Sentence #': 'Sentence: 41', 'Word': 'they'},
#  {'POS': 'VBP', 'Sentence #': 'Sentence: 41', 'Word': 'have'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 41', 'Word': 'arrested'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 41', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 41', 'Word': 'man'},
#  {'POS': 'WP', 'Sentence #': 'Sentence: 41', 'Word': 'who'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 41', 'Word': 'dressed'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 41', 'Word': 'as'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 41', 'Word': 'suicide'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 41', 'Word': 'bomber'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 41', 'Word': 'at'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 41', 'Word': 'a'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 41', 'Word': 'demonstration'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 41', 'Word': 'against'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 41', 'Word': 'the'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 41', 'Word': 'publication'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 41', 'Word': 'of'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 41', 'Word': 'cartoons'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 41', 'Word': 'depicting'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 41', 'Word': 'Islam'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 41', 'Word': "'s"},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 41', 'Word': 'Prophet'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 41', 'Word': 'Muhammad'},
#  {'POS': '.', 'Sentence #': 'Sentence: 41', 'Word': '.'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 42', 'Word': 'Bedfordshire'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 42', 'Word': 'police'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 42', 'Word': 'said'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 42', 'Word': 'Tuesday'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 42', 'Word': 'that'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 42', 'Word': 'Omar'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 42', 'Word': 'Khayam'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 42', 'Word': 'was'},
#  {'POS': 'VBN', 'Sentence #': 'Sentence: 42', 'Word': 'arrested'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 42', 'Word': 'in'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 42', 'Word': 'Bedford'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 42', 'Word': 'for'},
#  {'POS': 'VBG', 'Sentence #': 'Sentence: 42', 'Word': 'breaching'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 42', 'Word': 'the'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 42', 'Word': 'conditions'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 42', 'Word': 'of'},
#  {'POS': 'PRP$', 'Sentence #': 'Sentence: 42', 'Word': 'his'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 42', 'Word': 'parole'},
#  {'POS': '.', 'Sentence #': 'Sentence: 42', 'Word': '.'},
#  {'POS': 'NNS', 'Sentence #': 'Sentence: 43', 'Word': 'Police'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 43', 'Word': 'said'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 43', 'Word': 'the'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 43', 'Word': 'British'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 43', 'Word': 'Home'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 43', 'Word': 'Office'},
#  {'POS': 'VBD', 'Sentence #': 'Sentence: 43', 'Word': 'sought'},
#  {'POS': 'DT', 'Sentence #': 'Sentence: 43', 'Word': 'an'},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 43', 'Word': 'investigation'},
#  {'POS': 'IN', 'Sentence #': 'Sentence: 43', 'Word': 'of'},
#  {'POS': 'NNP', 'Sentence #': 'Sentence: 43', 'Word': 'Khayam'},
#  {'POS': 'POS', 'Sentence #': 'Sentence: 43', 'Word': "'s"},
#  {'POS': 'NN', 'Sentence #': 'Sentence: 43', 'Word': 'behavior'},
#  ...]

# %% [markdown]
# We need to transform our text input to vector using DictVectorizer and then split to train and test sets for carrying out further estimation

# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer


v = DictVectorizer(sparse=False)
X = v.fit_transform(X.to_dict('records'))
X.shape
# Out:
# (50000, 9774)

# %%
y = quick_df.Tag.values

# %%
classes = np.unique(y)
classes = classes.tolist()
classes
# Out:
# ['B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim',
#  'O']

# %% [markdown]
# Tag “O” is the most common tag and it will make our results look much better than they actual are. So we remove tag “O” when we evaluate classification metrics.

# %%
new_classes = classes.copy()
new_classes.pop()
new_classes
# Out:
# ['B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim']

# %%
X.shape, y.shape
# Out:
# ((50000, 9774), (50000,))

# %% [markdown]
# Let us now split, our training and test dataset using 70-30% split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=0)

# %% [markdown]
# Let us check shape of our newly obtained training and testing dataset

# %%
X_train.shape, y_train.shape
# Out:
# ((35000, 9774), (35000,))

# %%
X_test.shape, y_test.shape
# Out:
# ((15000, 9774), (15000,))

# %% [markdown]
# #### Algorithm Selection

# %% [markdown]
# As we have large dataset, training it is a problem while using same data to fit in memory, so will be using Out-of-core Algorithms which are designed to process data that is too large to fit into a single computer memory that support partial_fit method.

# %% [markdown]
# ### Naive Bayes classifier for multinomial models

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB(alpha=0.01)
nb.partial_fit(X_train, y_train, classes)
# Out:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred=nb.predict(X_test), y_true=y_test, labels = new_classes))
# Out:
#              precision    recall  f1-score   support
#
#       B-art       0.16      0.29      0.21        17
#       B-eve       0.12      0.36      0.18        11
#       B-geo       0.66      0.57      0.61       441
#       B-gpe       0.64      0.73      0.68       297
#       B-nat       0.33      0.67      0.44         3
#       B-org       0.48      0.49      0.48       272
#       B-per       0.39      0.48      0.43       233
#       B-tim       0.60      0.74      0.67       246
#       I-art       0.08      0.25      0.12         4
#       I-eve       0.54      0.64      0.58        11
#       I-geo       0.42      0.49      0.45       107
#       I-gpe       0.00      0.00      0.00        10
#       I-nat       0.00      0.00      0.00         2
#       I-org       0.47      0.51      0.49       180
#       I-per       0.53      0.45      0.49       279
#       I-tim       0.18      0.29      0.22        83
#
# avg / total       0.53      0.55      0.53      2196

# %% [markdown]
# ### Perceptron

# %%
from sklearn.linear_model import Perceptron

per = Perceptron(verbose=10, n_jobs=-1, max_iter=5)
per.partial_fit(X_train, y_train, classes)
# Out:
# -- Epoch 1-- Epoch 1-- Epoch 1-- Epoch 1
#
#
#
# Norm: 40.45, NNZs: 928, Bias: -4.000000, T: 35000, Avg. loss: 0.021657Norm: 10.77, NNZs: 110, Bias: -4.000000, T: 35000, Avg. loss: 0.001886
# Total training time: 1.01 seconds.
#
# Total training time: 0.96 seconds.Norm: 50.86, NNZs: 1458, Bias: -3.000000, T: 35000, Avg. loss: 0.042629
# Norm: 11.00, NNZs: 96, Bias: -3.000000, T: 35000, Avg. loss: 0.001400
# Total training time: 1.06 seconds.
#
# Total training time: 1.06 seconds.-- Epoch 1
#
# -- Epoch 1-- Epoch 1
#
# -- Epoch 1
# Norm: 8.43, NNZs: 53, Bias: -3.000000, T: 35000, Avg. loss: 0.000743
# Total training time: 0.90 seconds.
# -- Epoch 1
# Norm: 36.92, NNZs: 926, Bias: -3.000000, T: 35000, Avg. loss: 0.022857
# Total training time: 0.94 seconds.
# -- Epoch 1
# Norm: 42.78, NNZs: 1153, Bias: -4.000000, T: 35000, Avg. loss: 0.035686
# Total training time: 0.96 seconds.
# -- Epoch 1
# Norm: 35.34, NNZs: 718, Bias: -3.000000, T: 35000, Avg. loss: 0.018086
# Total training time: 0.97 seconds.
# -- Epoch 1
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.0s
# Norm: 9.64, NNZs: 87, Bias: -3.000000, T: 35000, Avg. loss: 0.001343
# Total training time: 1.11 seconds.
# -- Epoch 1
# Norm: 9.43, NNZs: 72, Bias: -3.000000, T: 35000, Avg. loss: 0.001171
# Total training time: 1.15 seconds.
# -- Epoch 1
# Norm: 25.18, NNZs: 443, Bias: -4.000000, T: 35000, Avg. loss: 0.009914
# Total training time: 1.14 seconds.
# -- Epoch 1
# Norm: 8.43, NNZs: 62, Bias: -3.000000, T: 35000, Avg. loss: 0.001314
# Total training time: 1.17 seconds.
# -- Epoch 1
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  12 out of  17 | elapsed:    4.2s remaining:    1.7s
# Norm: 6.16, NNZs: 27, Bias: -2.000000, T: 35000, Avg. loss: 0.000200
# Total training time: 1.16 seconds.
# Norm: 39.09, NNZs: 921, Bias: -4.000000, T: 35000, Avg. loss: 0.024000
# Total training time: 1.10 seconds.
# -- Epoch 1
# Norm: 46.01, NNZs: 1281, Bias: -5.000000, T: 35000, Avg. loss: 0.027629
# Total training time: 1.16 seconds.
# Norm: 21.98, NNZs: 350, Bias: -5.000000, T: 35000, Avg. loss: 0.009829
# Total training time: 1.11 seconds.
# [Parallel(n_jobs=-1)]: Done  14 out of  17 | elapsed:    5.3s remaining:    1.1s
# Norm: 52.86, NNZs: 1538, Bias: 2.000000, T: 35000, Avg. loss: 0.045743
# Total training time: 0.61 seconds.
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    5.9s finished
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       max_iter=5, n_iter=None, n_jobs=-1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=10, warm_start=False)

# %%
print(classification_report(y_pred=per.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#              precision    recall  f1-score   support
#
#       B-art       0.00      0.00      0.00        17
#       B-eve       0.25      0.09      0.13        11
#       B-geo       0.34      0.95      0.50       441
#       B-gpe       0.91      0.62      0.74       297
#       B-nat       0.00      0.00      0.00         3
#       B-org       0.61      0.27      0.38       272
#       B-per       0.67      0.42      0.52       233
#       B-tim       0.79      0.77      0.78       246
#       I-art       0.00      0.00      0.00         4
#       I-eve       0.75      0.27      0.40        11
#       I-geo       0.79      0.14      0.24       107
#       I-gpe       0.14      0.10      0.12        10
#       I-nat       0.00      0.00      0.00         2
#       I-org       0.67      0.19      0.29       180
#       I-per       0.84      0.24      0.37       279
#       I-tim       0.50      0.10      0.16        83
#
# avg / total       0.65      0.50      0.48      2196
# C:\Users\sugat\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Linear classifiers with SGD training

# %% [markdown]
# SGD is not any specific ML algorithm, but its an optimization function
#
# So,SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42) it is an implementation of Linear SVM
#
# While,
# SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42) . It is an implementation of Logisitic regression

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.partial_fit(X_train, y_train, classes)
# Out:
# C:\Users\sugat\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
print(classification_report(y_pred=sgd.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#              precision    recall  f1-score   support
#
#       B-art       0.00      0.00      0.00        17
#       B-eve       0.00      0.00      0.00        11
#       B-geo       0.73      0.51      0.60       441
#       B-gpe       0.96      0.53      0.68       297
#       B-nat       0.00      0.00      0.00         3
#       B-org       0.54      0.36      0.43       272
#       B-per       0.86      0.36      0.51       233
#       B-tim       0.94      0.67      0.78       246
#       I-art       0.00      0.00      0.00         4
#       I-eve       0.33      0.09      0.14        11
#       I-geo       0.64      0.42      0.51       107
#       I-gpe       0.00      0.00      0.00        10
#       I-nat       0.00      0.00      0.00         2
#       I-org       0.61      0.38      0.47       180
#       I-per       0.31      0.96      0.47       279
#       I-tim       0.00      0.00      0.00        83
#
# avg / total       0.66      0.51      0.53      2196
# C:\Users\sugat\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Passive Aggressive Classifier

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

pa =PassiveAggressiveClassifier()
pa.partial_fit(X_train, y_train, classes)
# Out:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#               fit_intercept=True, loss='hinge', max_iter=None, n_iter=None,
#               n_jobs=1, random_state=None, shuffle=True, tol=None,
#               verbose=0, warm_start=False)

# %%
print(classification_report(y_pred=pa.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#              precision    recall  f1-score   support
#
#       B-art       1.00      0.06      0.11        17
#       B-eve       0.33      0.18      0.24        11
#       B-geo       0.81      0.09      0.16       441
#       B-gpe       0.85      0.64      0.73       297
#       B-nat       0.00      0.00      0.00         3
#       B-org       0.20      0.88      0.33       272
#       B-per       0.88      0.34      0.49       233
#       B-tim       0.70      0.81      0.75       246
#       I-art       0.00      0.00      0.00         4
#       I-eve       1.00      0.09      0.17        11
#       I-geo       0.79      0.21      0.34       107
#       I-gpe       0.27      0.40      0.32        10
#       I-nat       0.00      0.00      0.00         2
#       I-org       0.61      0.37      0.46       180
#       I-per       0.80      0.34      0.48       279
#       I-tim       0.34      0.22      0.26        83
#
# avg / total       0.69      0.44      0.44      2196
# C:\Users\sugat\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
